# %%
# !git config --global user.email "dangduy291103@gmail.com"
# !git config --global user.name "duydang03"

# %%
# !git clone https://github.com/duydang03/Lane-Detection.git
# Out:
# Cloning into 'Lane-Detection'...
# ...

# %%
# %cd /content/Lane-Detection
# !ls
# Out:
# /content/Lane-Detection
# Lane-Detection

# %%
# !cp -r /content/project/* /content/Lane-Detection/
# Out:
# cp: cannot stat '/content/project/*': No such file or directory

# %%
# !mv /content/Lane-Detection/Lane-Detection/* /content/Lane-Detection/
# Out:
# mv: cannot move '/content/Lane-Detection/Lane-Detection/Lane-Detection' to '/content/Lane-Detection/Lane-Detection': Directory not empty

# %%
# !rm -rf /content/Lane-Detection/Lane-Detection

# %%
# !ls /content/Lane-Detection

# %%
# %cd /content/Lane-Detection
# !ls
# Out:
# /content/Lane-Detection

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Lane detection/"* /content/Lane-Detection/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/Lane detection/*': No such file or directory
